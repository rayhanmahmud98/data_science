# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random

# var_1 = random.sample(range(1,6),5)
# var_2 = random.sample(range(7,12),5)

# print("Var_1 =", var_1,"\n","Var_2 = " ,var_2)

var_1 = [1,2,3,4,5,6,7]
var_2 = [1,4,6,8,3,5,7]

x1 = pd.DataFrame({"Var_1":var_1,"Var_2":var_2})

sns.lineplot(x="Var_1",y="Var_2",data=x1)

plt.show()

# %%
plt.plot(var_1,var_2)
plt.show()

# %%
file_path = "taxis.csv"
df = pd.read_csv(file_path).head(30)
df
# Out:
#              pickup          dropoff  passengers  distance  fare   tip  tolls  \
# 0   3/23/2019 20:21  3/23/2019 20:27           1      1.60   7.0  2.15   0.00
# 1    3/4/2019 16:11   3/4/2019 16:19           1      0.79   5.0  0.00   0.00
# 2   3/27/2019 17:53  3/27/2019 18:00           1      1.37   7.5  2.36   0.00
# 3    3/10/2019 1:23   3/10/2019 1:49           1      7.70  27.0  6.15   0.00
# 4   3/30/2019 13:27  3/30/2019 13:37           3      2.16   9.0  1.10   0.00
# 5   3/11/2019 10:37  3/11/2019 10:47           1      0.49   7.5  2.16   0.00
# 6   3/26/2019 21:07  3/26/2019 21:17           1      3.65  13.0  2.00   0.00
# 7   3/22/2019 12:47  3/22/2019 12:58           0      1.40   8.5  0.00   0.00
# 8   3/23/2019 11:48  3/23/2019 12:06           1      3.63  15.0  1.00   0.00
# 9    3/8/2019 16:18   3/8/2019 16:26           1      1.52   8.0  1.00   0.00
# 10  3/16/2019 10:02  3/16/2019 10:22           1      3.90  17.0  0.00   0.00
# ...

# %%
sns.lineplot(x="pickup_zone",y="pickup_borough",data=df,hue="payment",style="payment",size=2,palette="Accent_r",dashes=False)
plt.grid()
plt.title("Python")
plt.show()
